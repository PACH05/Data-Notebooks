# %%
import pandas as pd

# %%
df = pd.read_csv('survey.csv')

# %%
df.head()
# Out:
#    rownames     Sex  Wr.Hnd  NW.Hnd  W.Hnd     Fold  Pulse     Clap  Exer  \
# 0         1  Female    18.5    18.0  Right   R on L   92.0     Left  Some
# 1         2    Male    19.5    20.5   Left   R on L  104.0     Left   NaN
# 2         3    Male    18.0    13.3  Right   L on R   87.0  Neither   NaN
# 3         4    Male    18.8    18.9  Right   R on L    NaN  Neither   NaN
# 4         5    Male    20.0    20.0  Right  Neither   35.0    Right  Some
#
#    Smoke  Height       M.I     Age
# 0  Never   173.0    Metric  18.250
# 1  Regul   177.8  Imperial  17.583
# 2  Occas     NaN       NaN  16.917
# 3  Never   160.0    Metric  20.333
# 4  Never   165.0    Metric  23.667

# %%
df.tail()
# Out:
#      rownames     Sex  Wr.Hnd  NW.Hnd  W.Hnd    Fold  Pulse   Clap  Exer  \
# 232       233  Female    18.0    18.0  Right  L on R   85.0  Right  Some
# 233       234  Female    18.5    18.0  Right  L on R   88.0  Right  Some
# 234       235  Female    17.5    16.5  Right  R on L    NaN  Right  Some
# 235       236    Male    21.0    21.5  Right  R on L   90.0  Right  Some
# 236       237  Female    17.6    17.3  Right  R on L   85.0  Right  Freq
#
#      Smoke  Height       M.I     Age
# 232  Never   165.1  Imperial  17.667
# 233  Never   160.0    Metric  16.917
# 234  Never   170.0    Metric  18.583
# 235  Never   183.0    Metric  17.167
# 236  Never   168.5    Metric  17.750

# %%
df.shape
# Out:
# (237, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  237 non-null    int64
#  1   Sex       236 non-null    object
#  2   Wr.Hnd    236 non-null    float64
#  3   NW.Hnd    236 non-null    float64
#  4   W.Hnd     236 non-null    object
#  5   Fold      237 non-null    object
#  6   Pulse     192 non-null    float64
#  7   Clap      236 non-null    object
#  8   Exer      213 non-null    object
#  9   Smoke     236 non-null    object
#  10  Height    209 non-null    float64
#  11  M.I       209 non-null    object
#  12  Age       237 non-null    float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 24.2+ KB

# %%
df.isnull().sum()
# Out:
# rownames     0
# Sex          1
# Wr.Hnd       1
# NW.Hnd       1
# W.Hnd        1
# Fold         0
# Pulse       45
# Clap         1
# Exer        24
# Smoke        1
# Height      28
# M.I         28
# Age          0
# dtype: int64

# %%
df.describe()
# Out:
#            Wr.Hnd      NW.Hnd       Pulse      Height         Age
# count  236.000000  236.000000  192.000000  209.000000  237.000000
# mean    18.669068   18.582627   74.151042  172.380861   20.374515
# std      1.878981    1.967068   11.687157    9.847528    6.474335
# min     13.000000   12.500000   35.000000  150.000000   16.750000
# 25%     17.500000   17.500000   66.000000  165.000000   17.667000
# 50%     18.500000   18.500000   72.500000  171.000000   18.583000
# 75%     19.800000   19.725000   80.000000  180.000000   20.167000
# max     23.200000   23.500000  104.000000  200.000000   73.000000

# %%
df.head()
# Out:
#              Sex  Wr.Hnd  NW.Hnd  W.Hnd     Fold  Pulse     Clap  Exer  Smoke  \
# rownames
# 1         Female    18.5    18.0  Right   R on L   92.0     Left  Some  Never
# 2           Male    19.5    20.5   Left   R on L  104.0     Left   NaN  Regul
# 3           Male    18.0    13.3  Right   L on R   87.0  Neither   NaN  Occas
# 4           Male    18.8    18.9  Right   R on L    NaN  Neither   NaN  Never
# 5           Male    20.0    20.0  Right  Neither   35.0    Right  Some  Never
#
#           Height       M.I     Age
# rownames
# 1          173.0    Metric  18.250
# 2          177.8  Imperial  17.583
# 3            NaN       NaN  16.917
# 4          160.0    Metric  20.333
# 5          165.0    Metric  23.667

# %%
df['Exer'].isnull().value_counts()
# Out:
# Exer
# False    213
# True      24
# Name: count, dtype: int64

# %%
df[df['Clap']== 'Left'].head()
# Out:
#     rownames     Sex  Wr.Hnd  NW.Hnd  W.Hnd    Fold  Pulse  Clap  Exer  Smoke  \
# 0          1  Female    18.5    18.0  Right  R on L   92.0  Left  Some  Never
# 1          2    Male    19.5    20.5   Left  R on L  104.0  Left   NaN  Regul
# 11        12    Male    21.0    21.0  Right  R on L   68.0  Left  Freq  Never
# 18        19    Male    20.5    20.5  Right  L on R    NaN  Left  Some  Never
# 20        21    Male    21.5    22.0  Right  R on L   72.0  Left  Freq  Never
#
#     Height       M.I     Age
# 0    173.0    Metric  18.250
# 1    177.8  Imperial  17.583
# 11     NaN       NaN  18.250
# 18   190.5  Imperial  19.750
# 20   190.5  Imperial  17.917

# %%
df[df['M.I'].notnull()]
# Out:
#      rownames     Sex  Wr.Hnd  NW.Hnd  W.Hnd     Fold  Pulse     Clap  Exer  \
# 0           1  Female    18.5    18.0  Right   R on L   92.0     Left  Some
# 1           2    Male    19.5    20.5   Left   R on L  104.0     Left   NaN
# 3           4    Male    18.8    18.9  Right   R on L    NaN  Neither   NaN
# 4           5    Male    20.0    20.0  Right  Neither   35.0    Right  Some
# 5           6  Female    18.0    17.7  Right   L on R   64.0    Right  Some
# ..        ...     ...     ...     ...    ...      ...    ...      ...   ...
# 232       233  Female    18.0    18.0  Right   L on R   85.0    Right  Some
# 233       234  Female    18.5    18.0  Right   L on R   88.0    Right  Some
# 234       235  Female    17.5    16.5  Right   R on L    NaN    Right  Some
# 235       236    Male    21.0    21.5  Right   R on L   90.0    Right  Some
# 236       237  Female    17.6    17.3  Right   R on L   85.0    Right  Freq
#
#      Smoke  Height       M.I     Age
# ...

# %%
import matplotlib.pyplot as plt

# %%
ratio = df['Sex'].value_counts()

# %%
ratio
# Out:
# Sex
# Female    118
# Male      118
# Name: count, dtype: int64

# %%
df['Sex'].isna().value_counts()
# Out:
# Sex
# False    236
# True       1
# Name: count, dtype: int64

# %%
df['Sex'].isna().value_counts()
# Out:
# Sex
# False    236
# True       1
# Name: count, dtype: int64

# %%
df.dropna(subset=['Sex'], inplace=True)

# %%
df.head()
# Out:
#    rownames     Sex  Wr.Hnd  NW.Hnd  W.Hnd     Fold  Pulse     Clap  Exer  \
# 0         1  Female    18.5    18.0  Right   R on L   92.0     Left  Some
# 1         2    Male    19.5    20.5   Left   R on L  104.0     Left   NaN
# 2         3    Male    18.0    13.3  Right   L on R   87.0  Neither   NaN
# 3         4    Male    18.8    18.9  Right   R on L    NaN  Neither   NaN
# 4         5    Male    20.0    20.0  Right  Neither   35.0    Right  Some
#
#    Smoke  Height       M.I     Age
# 0  Never   173.0    Metric  18.250
# 1  Regul   177.8  Imperial  17.583
# 2  Occas     NaN       NaN  16.917
# 3  Never   160.0    Metric  20.333
# 4  Never   165.0    Metric  23.667

# %%
sex_counts = df['Sex'].value_counts()

# %%
sex_counts.plot(kind='bar', color=['skyblue', 'pink'])
plt.title('Sex-wise Count')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
Exercise=df['Exer'].value_counts()

# %%
df.set_index(df['rownames'],inplace=True)

# %%
df
# Out:
#           rownames     Sex  Wr.Hnd  NW.Hnd  W.Hnd     Fold       Pulse  \
# rownames
# 1                1  Female    18.5    18.0  Right   R on L   92.000000
# 2                2    Male    19.5    20.5   Left   R on L  104.000000
# 3                3    Male    18.0    13.3  Right   L on R   87.000000
# 4                4    Male    18.8    18.9  Right   R on L   74.157068
# 5                5    Male    20.0    20.0  Right  Neither   35.000000
# ...            ...     ...     ...     ...    ...      ...         ...
# 233            233  Female    18.0    18.0  Right   L on R   85.000000
# 234            234  Female    18.5    18.0  Right   L on R   88.000000
# 235            235  Female    17.5    16.5  Right   R on L   74.157068
# 236            236    Male    21.0    21.5  Right   R on L   90.000000
# 237            237  Female    17.6    17.3  Right   R on L   85.000000
#
#              Clap  Exer  Smoke  Height       M.I     Age
# rownames
# ...

# %%
df.drop(['rownames'],axis=1, inplace=True)

# %%
df['Exer'].unique()
# Out:
# array(['Some', 'Freq'], dtype=object)

# %%
Exercise.sum()
# Out:
# 212

# %%
Exercise.plot(kind='pie')
plt.title('Exercise Data')
plt.show()

# %%
df['Exer'].fillna('Some',inplace=True)

# %% [markdown]
# Pulse Data Cleaning

# %%
df.head()
# Out:
#              Sex  Wr.Hnd  NW.Hnd  W.Hnd     Fold       Pulse     Clap  Exer  \
# rownames
# 1         Female    18.5    18.0  Right   R on L   92.000000     Left  Some
# 2           Male    19.5    20.5   Left   R on L  104.000000     Left  Some
# 3           Male    18.0    13.3  Right   L on R   87.000000  Neither  Some
# 4           Male    18.8    18.9  Right   R on L   74.157068  Neither  Some
# 5           Male    20.0    20.0  Right  Neither   35.000000    Right  Some
#
#           Smoke  Height       M.I     Age
# rownames
# 1         Never   173.0    Metric  18.250
# 2         Regul   177.8  Imperial  17.583
# 3         Occas     NaN       NaN  16.917
# 4         Never   160.0    Metric  20.333
# 5         Never   165.0    Metric  23.667

# %%
Pulse = df['Pulse'].value_counts()

# %%
Pulse.head()
# Out:
# Pulse
# 80.0    18
# 68.0    16
# 72.0    14
# 70.0    13
# 76.0    13
# Name: count, dtype: int64

# %%
df['Pulse'].isna().value_counts()
# Out:
# Pulse
# False    191
# True      45
# Name: count, dtype: int64

# %%
mean_heart_rate = df.Pulse.mean()
mean_heart_rate
# Out:
# 74.15706806282722

# %%
df['Pulse'].fillna(mean_heart_rate)
# Out:
# rownames
# 1       92.000000
# 2      104.000000
# 3       87.000000
# 4       74.157068
# 5       35.000000
#           ...
# 233     85.000000
# 234     88.000000
# 235     74.157068
# 236     90.000000
# 237     85.000000
# Name: Pulse, Length: 236, dtype: float64

# %%
df['Pulse'].isna().value_counts()
# Out:
# Pulse
# False    236
# Name: count, dtype: int64
